# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
amazon_review = pd.read_json('C:/Users/김기주/3-1project/data/Amazon_Fashion.jsonl', lines=True)
amazon_meta = pd.read_json('C:/Users/김기주/3-1project/data/meta_Amazon_Fashion.jsonl', lines=True)

# %%
print(amazon_review.columns)
print(amazon_meta.columns)
# Out:
# Index(['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id',
#        'timestamp', 'helpful_vote', 'verified_purchase'],
#       dtype='object')
# Index(['main_category', 'title', 'average_rating', 'rating_number', 'features',
#        'description', 'price', 'images', 'videos', 'store', 'categories',
#        'details', 'parent_asin', 'bought_together'],
#       dtype='object')

# %%
amazon_review.to_csv('C:/Users/김기주/3-1project/data/amazon_review.csv')
amazon_meta.to_csv('C:/Users/김기주/3-1project/data/amazon_meta.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 amazon_review.to_csv('C:/Users/김기주/3-1project/data/amazon_review.csv')
# ----> 2 amazon_meta.to_csv('C:/Users/김기주/3-1project/data/amazon_meta.csv')
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\core\generic.py:3964, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3953 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3955 formatter = DataFrameFormatter(
#    3956     frame=df,
#    3957     header=header,
#    (...)
#    3961     decimal=decimal,
#    3962 )
# -> 3964 return DataFrameRenderer(formatter).to_csv(
#    3965     path_or_buf,
#    3966     lineterminator=lineterminator,
#    3967     sep=sep,
#    3968     encoding=encoding,
#    3969     errors=errors,
#    3970     compression=compression,
#    3971     quoting=quoting,
#    3972     columns=columns,
#    3973     index_label=index_label,
#    3974     mode=mode,
#    3975     chunksize=chunksize,
#    3976     quotechar=quotechar,
#    3977     date_format=date_format,
#    3978     doublequote=doublequote,
#    3979     escapechar=escapechar,
#    3980     storage_options=storage_options,
#    3981 )
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\io\formats\csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\io\formats\csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\io\formats\csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File D:\anaconda3\envs\daconai\Lib\site-packages\pandas\io\formats\csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#     327     self.nlevels,
#     328     self.cols,
#     329     self.writer,
#     330 )
#
# File writers.pyx:56, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
amazon_review
# Out:
#          rating                                              title  \
# 0             5                                      Pretty locket
# 1             5                                                  A
# 2             2                                          Two Stars
# 3             1                                    Won’t buy again
# 4             5                               I LOVE these glasses
# ...         ...                                                ...
# 2500934       5  ... allowed them to be used to add military ri...
# 2500935       1                           Didn’t come with all ten
# 2500936       3                            Not checked for quality
# 2500937       5                                            Awesome
# 2500938       1                                  Empty plastic bag
#
#                                                       text images        asin  \
# 0        I think this locket is really pretty. The insi...     []  B00LOPVX74
# 1                                                    Great     []  B07B4JXK8D
# 2        One of the stones fell out within the first 2 ...     []  B007ZSEQ4Q
# 3        Crappy socks. Money wasted. Bought to wear wit...     []  B07F2BTFS9
# 4        I LOVE these glasses!  They fit perfectly over...     []  B00PKRFU4O
# ...                                                    ...    ...         ...
# 2500934  The tie tacks were the size that allowed them ...     []  B00YGFMQC0
# 2500935          Says ten tie clips but o only received 7.     []  B00YGFMQC0
# 2500936  When I received them 2-3 of them did not open ...     []  B00YGFMQC0
# 2500937                                     Great product.     []  B00YGFMQC0
# 2500938  I got an empty bag in my package of 10 that I ...     []  B00YGFMQC0
#
#         parent_asin                       user_id               timestamp  \
# 0        B00LOPVX74  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ 2020-01-09 00:06:34.489
# 1        B07B4JXK8D  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ 2020-12-20 01:04:06.701
# 2        B007ZSEQ4Q  AHITBJSS7KYUBVZPX7M2WJCOIVKQ 2015-05-23 01:33:48.000
# 3        B07F2BTFS9  AFVNEEPDEIH5SPUN5BWC6NKL3WNQ 2018-12-31 20:57:27.095
# 4        B00XESJTDE  AHSPLDNW5OOUK2PLH7GXLACFBZNQ 2015-08-13 14:29:26.000
# ...             ...                           ...                     ...
# 2500934  B00YGFMQC0  AFXSFD3FTZ2CLN3TYV4B63CQM5BQ 2016-06-24 20:12:38.000
# 2500935  B00YGFMQC0  AEH7WP5HGM6FGLSSC6GSTYUXBHGQ 2018-05-08 17:05:05.585
# 2500936  B00YGFMQC0  AEL2TSSBVLIPWQ7YVMK364DUYURQ 2016-12-17 22:28:31.000
# 2500937  B00YGFMQC0  AGZ6IIYSPCW4YXWH6VFEOI7MTBZA 2017-04-15 17:34:26.000
# 2500938  B00YGFMQC0  AGN3P7MZ3WYZQTPOCSIWNTHD5RDQ 2017-03-15 00:25:02.000
#
#          helpful_vote  verified_purchase
# 0                   3               True
# 1                   0               True
# 2                   3               True
# 3                   2               True
# 4                   0               True
# ...               ...                ...
# 2500934             0               True
# 2500935             0               True
# 2500936             0               True
# 2500937             1               True
# 2500938             1               True
#
# [2500939 rows x 10 columns]

# %%
num = len(amazon_review['asin'].unique().tolist())
print('제품 종류:',num,'개')
num = len(amazon_review['parent_asin'].unique().tolist())
print('카테고리 종류:',num,'개')

# %%
# parent_asin별로 모아서 개수 세기
print(amazon_review['parent_asin'].value_counts(ascending=False).head(50))

# %%
# print(amazon_meta[['rating_number', 'average_rating', 'parent_asin']].sort_values(by='rating_number', ascending=False).head(50).reset_index(drop=True))

# %%
# 실제 구매하지 않고 작성한 리뷰들은 삭제하기
c_a_r = amazon_review.copy()
c_a_r.drop(c_a_r[c_a_r['verified_purchase'] == False].index, inplace=True)
c_a_r
# Out:
#          rating                                              title  \
# 0             5                                      Pretty locket
# 1             5                                                  A
# 2             2                                          Two Stars
# 3             1                                    Won’t buy again
# 4             5                               I LOVE these glasses
# ...         ...                                                ...
# 2500934       5  ... allowed them to be used to add military ri...
# 2500935       1                           Didn’t come with all ten
# 2500936       3                            Not checked for quality
# 2500937       5                                            Awesome
# 2500938       1                                  Empty plastic bag
#
#                                                       text images        asin  \
# 0        I think this locket is really pretty. The insi...     []  B00LOPVX74
# 1                                                    Great     []  B07B4JXK8D
# 2        One of the stones fell out within the first 2 ...     []  B007ZSEQ4Q
# 3        Crappy socks. Money wasted. Bought to wear wit...     []  B07F2BTFS9
# 4        I LOVE these glasses!  They fit perfectly over...     []  B00PKRFU4O
# ...                                                    ...    ...         ...
# 2500934  The tie tacks were the size that allowed them ...     []  B00YGFMQC0
# 2500935          Says ten tie clips but o only received 7.     []  B00YGFMQC0
# 2500936  When I received them 2-3 of them did not open ...     []  B00YGFMQC0
# 2500937                                     Great product.     []  B00YGFMQC0
# 2500938  I got an empty bag in my package of 10 that I ...     []  B00YGFMQC0
#
#         parent_asin                       user_id               timestamp  \
# 0        B00LOPVX74  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ 2020-01-09 00:06:34.489
# 1        B07B4JXK8D  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ 2020-12-20 01:04:06.701
# 2        B007ZSEQ4Q  AHITBJSS7KYUBVZPX7M2WJCOIVKQ 2015-05-23 01:33:48.000
# 3        B07F2BTFS9  AFVNEEPDEIH5SPUN5BWC6NKL3WNQ 2018-12-31 20:57:27.095
# 4        B00XESJTDE  AHSPLDNW5OOUK2PLH7GXLACFBZNQ 2015-08-13 14:29:26.000
# ...             ...                           ...                     ...
# 2500934  B00YGFMQC0  AFXSFD3FTZ2CLN3TYV4B63CQM5BQ 2016-06-24 20:12:38.000
# 2500935  B00YGFMQC0  AEH7WP5HGM6FGLSSC6GSTYUXBHGQ 2018-05-08 17:05:05.585
# 2500936  B00YGFMQC0  AEL2TSSBVLIPWQ7YVMK364DUYURQ 2016-12-17 22:28:31.000
# 2500937  B00YGFMQC0  AGZ6IIYSPCW4YXWH6VFEOI7MTBZA 2017-04-15 17:34:26.000
# 2500938  B00YGFMQC0  AGN3P7MZ3WYZQTPOCSIWNTHD5RDQ 2017-03-15 00:25:02.000
#
#          helpful_vote  verified_purchase
# 0                   3               True
# 1                   0               True
# 2                   3               True
# 3                   2               True
# 4                   0               True
# ...               ...                ...
# 2500934             0               True
# 2500935             0               True
# 2500936             0               True
# 2500937             1               True
# 2500938             1               True
#
# [2337702 rows x 10 columns]

# %%
# 실 구매자들의 리뷰만 모아서 parent_asin별 개수세기
print(c_a_r['parent_asin'].value_counts(ascending=False).head(50))
# Out:
# parent_asin
# B09TXZHKLG    7202
# B09KHSM7BB    6206
# B09M6X79V9    4033
# B07GKLQ5KV    3364
# B09H6MXJ71    3084
# B084RYPGXN    2600
# B09WJSHQFL    2474
# B09QFJGKM5    2354
# B07CQ84KLT    2060
# B07BM9GWG7    1945
# B07JWLTCLX    1820
# B0BVMLJTFS    1616
# B0C4WSH5LC    1549
# B09Y3TXYF1    1509
# B0045H0L1W    1482
# B07VPGY6FX    1375
# B01GKAEC6Q    1348
# B0C3G9447V    1345
# B08F1V3KB9    1338
# B06W57G8QX    1265
# B0B2KL8C8Q    1236
# B07Q2QT2SK    1212
# B088K6Y2WG    1187
# B079RMS9ZG    1164
# B06XWK1RCB    1164
# B0B16Q1854    1160
# B009R09Z8W    1140
# B09TXPYLQF    1084
# B0B12PBSTG    1071
# B0871C2SJJ    1071
# B09JB3B36S    1062
# B0928FSGGD    1051
# B07FCW972S    1032
# B09MJ6NSNM    1022
# B084LJ5ZJ5     953
# B097RFTKJP     899
# B0BL8ZHRMZ     898
# B07BMCRRYG     884
# B0B14FJ5SS     876
# B07XD71F1H     859
# B07CM4C9BD     845
# B07PHW2CWH     823
# B076MYYDLZ     803
# B07YSSNLSW     788
# B01JUP0DLQ     784
# B07BJ9G6Q9     765
# B07S8KMCQW     751
# B00QETU2MM     750
# B08HM3Y85H     748
# B076QD9NP1     741
# Name: count, dtype: int64

# %%
fin_df = c_a_r[c_a_r['parent_asin'].isin(['B09KHSM7BB', 'B09M6X79V9', 'B09H6MXJ71', 'B07CQ84KLT', 'B07BM9GWG7', 'B0BVMLJTFS', 'B08F1V3KB9', 'B0B2KL8C8Q', 'B009R09Z8W', 'B0928FSGGD', 'B09MJ6NSNM',
                                               'B084LJ5ZJ5', 'B097RFTKJP', 'B07XD71F1H', 'B07YSSNLSW', 'B076QD9NP1'])].sort_values('parent_asin').reset_index(drop=True)
fin_df
# Out:
#        rating                                              title  \
# 0           5                                      Great! Great!
# 1           4  thinner than I would like, but fair for the price
# 2           5                                            Hoddies
# 3           5                                          Great fit
# 4           5                                   My son loves it.
# ...       ...                                                ...
# 28966       2                                      Not worth it.
# 28967       5                Great for working out for lounging!
# 28968       5                                           Buy them
# 28969       5                                              Nice!
# 28970       5                                              Happy
#
#                                                     text images        asin  \
# 0      I absolutely love the color and the thickness....     []  B0147ZXS5W
# 1      thinner than I would like, but fair for the pr...     []  B00OEF1Q9G
# 2      These are my favorite hoodies. I must have 12 ...     []  B00OEZ3716
# 3                          Love the color and fits well.     []  B00O558WWY
# 4      My son loves it and wears it constantly. Beefy...     []  B00MNNIYRS
# ...                                                  ...    ...         ...
# 28966  This product was shown as a hot pink pant legg...     []  B07MHK3FFL
# 28967                                     Perfect dupes!     []  B099F6J13V
# 28968  I don’t often leave reviews but I love these s...     []  B08PXQFPZH
# 28969  Super comfy and not see through. Very flatteri...     []  B07S8PNPM4
# 28970               Very happy with my delivery and item     []  B07S8PNPM4
#
#       parent_asin                       user_id               timestamp  \
# 0      B009R09Z8W  AGPST67TWB7SFRSPDXCDOB2VHELA 2019-02-21 06:47:03.912
# 1      B009R09Z8W  AFUJBKHTVFITEGJPUVNGG4RBU6SQ 2015-02-03 21:50:44.000
# 2      B009R09Z8W  AHYC43D3W3OSR7CSGZI2FU6IT6ZA 2022-03-24 16:44:26.591
# 3      B009R09Z8W  AG4ES4AI54GK2BFIYT7YZR3YMQXA 2021-06-01 11:48:58.968
# 4      B009R09Z8W  AGNHNKWELUNPQWDEKHP6J77LF2QA 2016-01-13 05:37:58.000
# ...           ...                           ...                     ...
# 28966  B0BVMLJTFS  AGAEEN6G7BGSKWOBNTT2QTCA2OOA 2020-07-20 14:44:09.297
# 28967  B0BVMLJTFS  AEEGB7LM7KCIQGPXP2P3QEGNCIIQ 2022-03-06 19:16:36.298
# 28968  B0BVMLJTFS  AHK4BHCB4PFRBMLHSOKKZKETES4A 2023-01-16 14:38:12.693
# 28969  B0BVMLJTFS  AGTLALTVF5G43ZR63YUAAPEB7L6A 2019-12-08 03:47:03.011
# 28970  B0BVMLJTFS  AFL3BMW6ZZMWHTXH7KDSUHHHZ2WA 2021-02-07 19:21:37.995
#
#        helpful_vote  verified_purchase
# 0                 0               True
# 1                 0               True
# 2                 0               True
# 3                 1               True
# 4                 0               True
# ...             ...                ...
# 28966             0               True
# 28967             0               True
# 28968             0               True
# 28969             0               True
# 28970             0               True
#
# [28971 rows x 10 columns]

# %%
c_fin_df = fin_df['rating'].value_counts()
c_fin_df
# Out:
# rating
# 5    18620
# 4     4242
# 3     2510
# 1     2073
# 2     1526
# Name: count, dtype: int64

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.figure(figsize=(10, 6))
# plt.hist(fin_df['rating'], bins=len(c_fin_df), edgecolor='black')
plt.bar(c_fin_df.index, c_fin_df, color='green')
plt.xlabel('리뷰 평점')
plt.ylabel('인원수')
plt.title('리뷰 평점 분포표')
plt.show()

# %%
df['text_length'] = fin_df['text'].str.len()
df
# Out:
# 0                                                             54
# 1                                                            102
# 2                                                            179
# 3                                                             29
# 4                                                             67
#                                      ...
# 28967                                                         14
# 28968                                                        131
# 28969                                                         67
# 28970                                                         36
# text_length    0         54
# 1        102
# 2        179
# 3      ...
# Name: text, Length: 28972, dtype: object

# %%
text_length_counts = df['text_length'].value_counts()

plt.figure(figsize=(10, 6))
plt.hist(df['text_length'], bins=60, edgecolor='black')
plt.xlabel('글자 길이')
plt.ylabel('글자수')
plt.xticks(range(0, 3000, 200))
plt.title('글자수 분포표')
plt.show()
